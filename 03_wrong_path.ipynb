# %% [markdown]
# # Break and fix
# Predict the error, run it, explain its cause and repair it.

# %%
with open("site_inspection_log.csv") as f:
    print(f.readline())
# Out:
# reading_id,crack_width_mm

# %% [markdown]
# # Week 2 proof of life
# CML3112. Set STUDENT_ID to your Student Registration Number, including slashes (fictional example only: 99/TEST/000/DEMO-X). Run cells in order.

# %%
STUDENT_ID = "24/1401/BSCE-J"
COHORT = "CML3112"

# %%
print("Hello from CML3112")
proof_sum = 2 + 2
print(proof_sum)
# Out:
# Hello from CML3112
# 4

# %%
readings = 12

# %%
readings = readings + 5
print(readings)
# Out:
# 17

# %% [markdown]
# Run the previous cell three times. Explain the changing result below, then restart and run all.

# %% [markdown]
# My explanation: when I ran the readings = readings + 5 cell the first time, it printed 17, because readings was 12 and the cell added 5. When I ran it again it printed 22, and then 27 on the third run. The cell doesn't reset readings; it adds 5 to whatever value is currently stored in the notebook's memory, so each run builds on the last one. After Restart and Run All, the memory is cleared and every cell runs once in order from the top, so readings starts at 12 again and the final result is 17.

# %%
import csv
with open("site_inspection_log.csv", newline="") as f:
    rows = list(csv.DictReader(f))
print(len(rows))
# Out:
# 4

# %% [markdown]
# After Restart and Run All, expected outputs include 4, 17 and 4 rows. Save with slashes replaced by underscores in the filename only, for example 99_TEST_000_DEMO-X_W02.ipynb.

# %% [markdown]
# # Break and fix
# Predict the error, run it, explain its cause and repair it.

# %%
readings = 12
readings = readings + 5
print(readings)  # expected fresh-run result: 17
# Out:
# 17
